# %%
#Importancion de modulos
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import VerticalPitch, Pitch

# %%
#Escoger colores
text_color = 'w'

# %%
data = pd.read_csv('shotsmap.csv')

# %%
data
# Out:
#            team shotType   situation  time             Futbolista     x     y
# 0           IDV     miss    assisted     7       Patrik Mercado    26.1  24.6
# 1           IDV     goal    assisted    11        Michael Hoyos    10.9  39.1
# 2           IDV     goal    assisted    21     Claudio Spinelli     2.4  46.0
# 3           IDV     miss    assisted    29    Thiago Santamaría    29.4  76.3
# 4           IDV    block    assisted    38       Patrik Mercado    20.4  36.1
# 5           IDV     miss      corner    40     Claudio Spinelli    11.6  47.3
# 6           IDV     miss    assisted    43       Patrik Mercado    29.5  48.5
# 7           IDV    block   free-kick    90       Junior Sornoza    70.2  20.5
# 8   River Plate     goal      corner     8      Sebastián Driussi  50.7   3.6
# 9   River Plate     miss    assisted    16       Giuliano Galoppo  39.9  27.3
# 10  River Plate     goal     regular    26     Luis Felipe Zárate  52.0   3.1
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 6.5))
fig.set_facecolor('#332a49')
ax.patch.set_facecolor('#332a49') 

pitch = Pitch(pitch_type='opta', line_color='#cfcfcf', line_zorder=3, pitch_color='#332a49')

pitch.draw(ax=ax)
plt.scatter(data['y'], data['x'], c='#fff', s=120, alpha=.7)

plt.title('Mapa de disparos del River vs IDV 2025', fontsize=15, c='#fff')
# Out:
# Text(0.5, 1.0, 'Mapa de disparos del River vs IDV 2025')
